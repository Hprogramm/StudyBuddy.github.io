# %% [markdown]
# <a href="https://colab.research.google.com/github/Hprogramm/StudyBuddy.github.io/blob/main/Final_Assignment_Fall_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # IDS103: Statistical Intuitions and Applications

# %% [markdown]
# ## Assignment 3: Research Report
#
# ### **Instructions**:
# You will sumbit three files as part of your assignment:
#
# 1. Your group's **research report**. This is your main submission and the item that you will be graded on.
#
# 2. Your **ipynb file**. This is a secondary resource. It must be included in a zip folder to show your professor how you conducted your analyses and obtained your visualizations and results.
#
# 3. Your group's dataset (i.e., csv file). This must also be included in the zip folder.
#
#
# Below you will find FIVE datasets.Your group will need to select **ONE** of these dataset to analyses and create a research report on.

# %% [markdown]
# ![Screenshot 2024-11-19 at 9.00.22 PM.png](data:image/png;base64,...)

# %% [markdown]
# ## Your group should choose only ONE dataset to work on!

# %% [markdown]
# # DataSet 1
# **Employee Satisfaction and Compensation**
#
# A multinational technology company is conducting an internal study to assess the relationship between employee experience, job satisfaction, commute challenges, and performance. The company has diverse departments, including Software Development, Marketing, and Product Management, with employees working both remotely and on-site. They want to evaluate how these factors influence employee performance and retention.
#
# The variables in this study include:
#
# * Years of Experience: Total years in the field, potentially influencing salary and promotion opportunities.
#
# * Salary: Annual compensation (in thousands), influenced by experience, department, and performance.
#
# * Job Satisfaction: Satisfaction score (1-10), with higher values indicating greater satisfaction.
#
# * Stress Level: Perceived stress score (1-10), with higher values reflecting higher stress.
#
# * Commute Distance: Distance from home to work (in km), potentially correlating with stress and satisfaction.
#
# * Gender: Employee’s gender (Male/Female), used to analyze possible differences in pay and promotions.
#
# * Department: Employee’s department, which may impact salary, satisfaction, and performance.
#
# * Promotion Last Year: Whether the employee was promoted last year (Yes/No), potentially linked to satisfaction and performance.
#
# * Work Mode: Work arrangement (Remote/On-site), impacting satisfaction, stress, and work-life balance.
#
# * Performance Rating: Performance score (1-10), with higher values indicating better performance, potentially linked to salary and promotion opportunities.

# %%
# Load the following libraries so that they can be applied in the subsequent code blocks

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
# The code below will generate a random sample of 300 participants for you to analyze.

# You need to replace "Group_Name" in the code below with your own full name.
#You need to Replace Group_ID with your own group ID number for reproducibility.
# The code will then generate a csv file that is labeled with your group name and which contains a random sample of 300 individuals.
# REMEMBER: you need to submit this csv file in the zip folder when submitting your assignment.

student_name = "Group_Name: Employee Satisfaction and Compensation"  # Replace "Group_Name" with your initials separated by a comma

file_name = f'{student_name}.csv'

try:
    df = pd.read_csv(file_name)  # Read the existing file if it exists
except FileNotFoundError:
    original_data = pd.read_csv("https://raw.githubusercontent.com/ZUCourses/SIA-Public/refs/heads/main/Assignment_3_Employee_Satisfaction_and_Compensation.csv")
    df = original_data.sample(300, random_state=Group_ID)  # Replace Group_ID with your own Group number for reproducibility
    df.to_csv(file_name, index=False)  # Save the sample to a CSV file
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
df.head()  # This only displays the first five entries of sample.

# %% [markdown]
# # DataSet 2
# **Diabetes Classification**
#
# This dataset contains clinical data from a number of patients that have been analyzed to examine cardiovascular health and kidney function. This data is important for evaluating the risk of heart disease and diabetes, as well as the impaired kidney function often associated with these conditions.
# * Age: Represents the age of the patient in years. Age can be a risk factor for diabetes, as the risk of diabetes increases with age.
# * Gender: Indicates the gender of the patient, which can be a factor in the prediction of diabetes. Some studies suggest that women may have a different risk than men in developing diabetes.
# * Body Mass Index (BMI): BMI is a measure that uses a person's height and weight to determine whether they are in the normal weight, overweight, or obese category. A high BMI is associated with a higher risk of diabetes.
# * Chol: total cholesterol level in the blood. Cholesterol is a fat found in the blood and can come from foods consumed and also be produced by the body. High cholesterol can be a risk factor for heart disease and diabetes.
# * TG (Triglycerides): Represents the level of triglycerides in the blood. Triglycerides are a type of fat found in the blood, and high levels can also increase the risk of heart disease and diabetes.
# * HDL (High-Density Lipoprotein): Is the ""good"" cholesterol that helps transport excess cholesterol from body tissues back to the liver for further processing or excretion. High levels of HDL are usually considered good for heart health.
# * LDL (Low-Density Lipoprotein): Is the ""bad"" cholesterol that can cause plaque buildup in the arteries, increasing the risk of heart disease and stroke. High LDL levels can be a risk factor for diabetes.
# * Cr (Creatinine): A waste product of muscle metabolism that is excreted from the body through the kidneys. Creatinine levels in the blood can provide information about kidney function. Kidney disease may be linked to the risk of diabetes.
# * BUN (Blood Urea Nitrogen): Is a measure used to evaluate kidney and liver function. High levels of BUN may indicate kidney or liver disorders that can be related to diabetes.
# * Diagonisis: An indicator that someone has diabetes.

# %%
# Load the following libraries so that they can be applied in the subsequent code blocks

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
# The code below will generate a random sample of 300 participants for you to analyze.

# You need to replace "Group_Name" in the code below with your own full name.
#You need to Replace Group_ID with your own group ID number for reproducibility.
# The code will then generate a csv file that is labeled with your group name and which contains a random sample of 300 individuals.
# REMEMBER: you need to submit this csv file in the zip folder when submitting your assignment.

student_name = "Group_Name: Diabetes Classification"  # Replace "Group_Name" with your initials separated by a comma

file_name = f'{student_name}.csv'

try:
    df = pd.read_csv(file_name)  # Read the existing file if it exists
except FileNotFoundError:
    original_data = pd.read_csv("https://raw.githubusercontent.com/ZUCourses/SIA-Public/refs/heads/main/Diabetes%20Classification.csv")
    df = original_data.sample(300, random_state=Group_ID)  # Replace Group_ID with your own Group number for reproducibility
    df.to_csv(file_name, index=False)  # Save the sample to a CSV file
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
df.head()  # This only displays the first five entries of sample.

# %% [markdown]
# # DataSet 3
# **Student Performance Factors**
#
# This dataset provides a comprehensive overview of various factors affecting student performance in exams. It includes information on study habits, attendance, parental involvement, and other aspects influencing academic success.
#
# * Hours_Studied: Number of hours spent studying per week.
# * Attendance: Percentage of classes attended.
# * Parental_Involvement: Level of parental involvement in the student's education (Low, Medium, High).
# * Access_to_Resources: Availability of educational resources (Low, Medium, High).
# * Extracurricular_Activities: Participation in extracurricular activities (Yes, No).
# * Sleep_Hours: Average number of hours of sleep per night.
# * Previous_Scores: Scores from previous exams.
# * Motivation_Level: Student's level of motivation (Low, Medium, High).
# * Internet_Access: Availability of internet access (Yes, No).
# * Tutoring_Sessions: Number of tutoring sessions attended per month.
# * Family_Income: Family income level (Low, Medium, High).
# * Teacher_Quality: Quality of the teachers (Low, Medium, High).
# * School_Type: Type of school attended (Public, Private).
# * Peer_Influence: Influence of peers on academic performance (Positive, Neutral, Negative).
# * Physical_Activity: Average number of hours of physical activity per week.
# * Learning_Disabilities: Presence of learning disabilities (Yes, No).
# * Parental_Education: Level- Highest education level of parents (High School, College, Postgraduate).
# * Distance_from_Home: Distance from home to school (Near, Moderate, Far).
# * Gender: Gender of the student (Male, Female).
# * Exam_Score: Final exam score.

# %%
# Load the following libraries so that they can be applied in the subsequent code blocks

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
# The code below will generate a random sample of 300 participants for you to analyze.

# You need to replace "Group_Name" in the code below with your own full name.
#You need to Replace Group_ID with your own group ID number for reproducibility.
# The code will then generate a csv file that is labeled with your group name and which contains a random sample of 300 individuals.
# REMEMBER: you need to submit this csv file in the zip folder when submitting your assignment.

student_name = "Group_Name: Student Performance Factors"  # Replace "Group_Name" with your initials separated by a comma

file_name = f'{student_name}.csv'

try:
    df = pd.read_csv(file_name)  # Read the existing file if it exists
except FileNotFoundError:
    original_data = pd.read_csv("https://raw.githubusercontent.com/ZUCourses/SIA-Public/refs/heads/main/Student%20Performance%20Factors.csv")
    df = original_data.sample(300, random_state=Group_ID)  # Replace Group_ID with your own Group number for reproducibility
    df.to_csv(file_name, index=False)  # Save the sample to a CSV file
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
df.head()  # This only displays the first five entries of sample.

# %% [markdown]
# # DataSet 4
# **Student Health**
#
# This dataset is used to assess health risks among college students involved in academic and entrepreneurial activities. The data is structured to support machine learning models that predict health conditions related to stress, physical strain, and mental well-being. Each row represents an individual student’s health, workload, and lifestyle characteristics.
#
# The variables in this study include:
#
# * Student_ID: Unique identifier for each student.
# * Age: Demographic information relevant to physiological data interpretation.
# * Gender: Demographic information relevant to physiological data interpretation.
# * Heart_Rate: Physiological measurements gathered from biosensors, indicative of cardiovascular health.
# * Blood_Pressure_Systolic: Physiological measurements gathered from biosensors, indicative of cardiovascular health.
# * Blood_Pressure_Diastolic: Physiological measurements gathered from biosensors, indicative of cardiovascular health.
# * Stress_Level_Biosensor: Biosensor stress levels on a scale of 1 to 10.
# * Stress_Level_Self_Report: Self-reported stress levels on a scale of 1 to 10.
# * Physical_Activity: Categorical variable indicating physical activity level (Low, Moderate, High).
# * Sleep_Quality: Categorical variables indicating sleep quality (Poor, Moderate, Good).
# * Mood: Self-reported emotional state categorized as 'Happy', 'Neutral', or 'Stressed'.
# * Study_Hours: Weekly hours dedicated to study, which is a major factor contributing to workload.
# * Project_Hours: Weekly hours dedicated to entrepreneurial activities, which is a major factor contributing to workload.
# * Health_Risk_Level: Target label derived based on stress and lifestyle indicators, categorized as Low, Moderate, or High risk.

# %%
# Load the following libraries so that they can be applied in the subsequent code blocks

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
# The code below will generate a random sample of 300 participants for you to analyze.

# You need to replace "Group_Name" in the code below with your own full name.
#You need to Replace Group_ID with your own group ID number for reproducibility.
# The code will then generate a csv file that is labeled with your group name and which contains a random sample of 300 individuals.
# REMEMBER: you need to submit this csv file in the zip folder when submitting your assignment.

student_name = "Group_Name: Students_Health"  # Replace "Group_Name" with your initials separated by a comma

file_name = f'{student_name}.csv'

try:
    df = pd.read_csv(file_name)  # Read the existing file if it exists
except FileNotFoundError:
    original_data = pd.read_csv("https://raw.githubusercontent.com/ZUCourses/SIA-Public/refs/heads/main/student_health_data.csv")
    df = original_data.sample(300, random_state=Group_ID)  # Replace Group_ID with your own Group number for reproducibility
    df.to_csv(file_name, index=False)  # Save the sample to a CSV file
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
df.head()  # This only displays the first five entries of sample.

# %% [markdown]
# # DataSet 5
# **Airline Customer Satisfaction**
#
# An airline company is conducting a study to understand the factors influencing customer satisfaction. The study analyzes a dataset of passengers traveling for business purposes in the Business Class. Passengers are categorized based on loyalty (loyal/disloyal) and various aspects of their travel experience are rated on a scale from 1 to 5. The airline aims to identify key areas of improvement in services and understand the relationship between passenger demographics, service ratings, delays, and overall satisfaction levels.
#
# List of Variables
#
# 1.        Gender: The gender of the passenger (e.g., Female, Male).
# 2.        Customer_Type: Whether the customer is loyal or disloyal.
# 3.        Age: The age of the passenger (in years).
# 4.        Type_of_Travel: The purpose of travel (e.g., Business travel, Personal travel).
# 5.        Class: Travel class (e.g., Business, Economy).
# 6.        Flight_Distance: The distance of the flight (in miles).
# 7.        Inflight_wifi_service: Passenger's rating of inflight Wi-Fi service (1 = very poor to 5 = excellent).
# 8.        Departure/Arrival_time_convenient: Rating of departure/arrival time convenience (1 = very poor to 5 = excellent).
# 9.        Food_and_drink: Rating of food and drink quality (1 = very poor to 5 = excellent).
# 10.        Seat_comfort: Rating of seat comfort (1 = very poor to 5 = excellent).
# 11.        Inflight_entertainment: Rating of inflight entertainment options (1 = very poor to 5 = excellent).
# 12.        Inflight_service: Rating of inflight service quality (1 = very poor to 5 = excellent).
# 13.        Cleanliness: Rating of cabin cleanliness (1 = very poor to 5 = excellent).
# 14.        Departure_Delay_in_Minutes: Delay in departure (in minutes).
# 15.        Arrival_Delay_in_Minutes: Delay in arrival (in minutes).
# 16.        Satisfaction: Overall satisfaction level (neutral_or_dissatisfied, satisfied).

# %%
# Load the following libraries so that they can be applied in the subsequent code blocks

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
# The code below will generate a random sample of 300 participants for you to analyze.

# You need to replace "Group_Name" in the code below with your own full name.
#You need to Replace Group_ID with your own group ID number for reproducibility.
# The code will then generate a csv file that is labeled with your group name and which contains a random sample of 300 individuals.
# REMEMBER: you need to submit this csv file in the zip folder when submitting your assignment.

student_name = "Group_Name: Airline Customer Satisfaction"  # Replace "Group_Name" with your initials separated by a comma

file_name = f'{student_name}.csv'

try:
    df = pd.read_csv(file_name)  # Read the existing file if it exists
except FileNotFoundError:
    original_data = pd.read_csv("https://raw.githubusercontent.com/ZUCourses/SIA-Public/refs/heads/main/airline_passengers.csv")
    df = original_data.sample(300, random_state=Group_ID)  # Replace Group_ID with your own Group number for reproducibility
    df.to_csv(file_name, index=False)  # Save the sample to a CSV file
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
df.head()  # This only displays the first five entries of sample.

# %% [markdown]
# ## Reference codes
#
# **IMPORTANT NOTE:**
#
# Based on the **#CompProgramDesign (LO): Generate working programs in a computer language to solve computational problems and identify and resolve any bugs that may arise.**
# You need to carefully **utilize** the suggested code below. **Adjust** it according to your data, and **ensure you find and fix any errors**.

# %%
#CI for proportions:

def confidence_interval(n, p, z):  # n: sample size, p: sample proportion, z: Z-score for desired confidence level
SE = (p * (1 - p) / n) ** 0.5  # Standard Error calculation based on sample proportion margin_of_error = z * SE  # Calculate margin of error
lowbound = p - margin_of_error  # Lower bound of confidence interval
highbound = p + margin_of_error  # Upper bound of confidence interval
print("CI:", [round(lowbound, 3), round(highbound, 3)])

# %%
#CI for One mean:

import statsmodels.stats.api as sms
X1 = df['your_column_name']  # Replace 'your_column_name' with the actual column name you want to analyze

print(sms.DescrStatsW(X1).tconfint_mean(alpha=0.05))

# %%
#Column chart:
import pandas
import matplotlib.pyplot as plt
df = pandas.read_csv("Add here the sampled data path link")
plt.hist(df['Variable'], 15)
df['Variable'].describe() #returns descriptive statistics

# %%
#95% confidence intervals for the mean difference by gender in the population
import statsmodels.stats.api as sm
import pandas
X1 = df.loc[df["Gender"]=="Male", "your_column_name"] # Replace 'your_column_name' with the actual column name you want to analyze
X2 = df.loc[df["Gender"]=="Female", "your_column_name"]  # Replace 'your_column_name' with the actual column name you want to analyze
cm = sm.CompareMeans(sm.DescrStatsW(X1), sm.DescrStatsW(X2))
print (cm.tconfint_diff(alpha=0.05, usevar='unequal'))

# %%
#Calculate the T-statistic and P-value for hypothesis testing for one mean.

import scipy.stats as stats
import pandas
df = pandas.read_csv("Add here the sampled data path")
X1 = df["Variable"]
# perform one sample t-test
t_stat, p_value = stats.ttest_1samp(X1, popmean= Population_mean) #Replace Population_mean with your population mean
print("T-statistic value: ", t_stat)
print("P-Value: ", p_value)

# %%
#Calculate the p-value for the difference between two means, filtered by gender.
import scipy.stats as stats
import pandas
df = pandas.read_csv("Add here the sampled data path link")
# perform two sample t-test
male = df.loc[df["Gender"]=="male", "Variable"]
female = df.loc[df["Gender"]=="female", "Variable"]
t_stat, p_value = stats.ttest_ind(male, female)
print("T-statistic value: ", t_stat)
print("P-Value: ", p_value)

# %%
#Confidence interval for the difference between two means (filtered by gender)

import statsmodels.stats.api as sm
import pandas
df = pandas.read_csv("Add here the sampled data path link")
X1 = df.loc[df["Gender"]=="male", "Variable"]
X2 = df.loc[df["Gender"]=="female", "Variable"]
cm = sm.CompareMeans(sm.DescrStatsW(X1), sm.DescrStatsW(X2))
print (cm.tconfint_diff(alpha=0.05, usevar='unequal'))

# %%
#Double Boxplot chart:

import pandas
import matplotlib.pyplot as plt
from numpy import percentile
df = pandas.read_csv("Add here the sampled data path link")
male=df[df["Gender"]=="male"]
female=df[df["Gender"]=="female"]

#create boxplots side by side
data1=male['Variable']
data2=female['Variable']
data = list([data1, data2])
fig, ax = plt.subplots()
ax.set_xticklabels(['male', 'female'])
plt.grid(axis="y")
plt.boxplot(data)
#descriptive statistics
print ("Descriptive Statistics for Male Participants")
print(male['Variable'].describe())
print ("Descriptive Statistics for Female Participants")
print(female['Variable'].describe())

# %%
#Scatter Plot:
#Sample code:
import pandas
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import statsmodels.api as statsmodels
import seaborn as sns

def regression_equation(column_x, column_y):
   # fit the regression line using "statsmodels" library:
   X= df[column_x]
   X = statsmodels.add_constant(X)
   Y = df[column_y]
   regressionmodel = statsmodels.OLS(Y,X).fit() #OLS stands for "ordinary least squares"
   print('R2: ', round(regressionmodel.rsquared, 3))
   SE=np.sqrt(regressionmodel.mse_resid)
   print ('SE=', round(SE, 3))


    #display the correlation coefficient
   correlation_coefficient=stats.stats.pearsonr(df[column_x],df[column_y])[0]
   print("correlation_coefficient=", round(correlation_coefficient,3))


   # extract regression parameters from model, rounded to 2 decimal places and print the regression equation:
   slope = round(regressionmodel.params[1],3)
   intercept = round(regressionmodel.params[0],3)
   print("Regression equation: "+column_y+" = ",slope,"* "+column_x+" + ",intercept)


   #display the scatter plot with the line of best fit
   plt.scatter(df[column_x], Y, color='green')
   plt.xlabel(column_x)
   plt.ylabel(column_y)
   plt.plot(df[column_x], regressionmodel.params[1]*df[column_x]+regressionmodel.params[0], color='red')
   plt.show()

regression_equation("Independent Variable", "Dependent Variable")
